# %% [markdown]
# ## 1.03 Anatomy of a Figure

# %% [markdown]
# <img src="anatomy-of-a-plot.png" alt="anatomy of a matplotlib plot" height="500">

# %%
# %matplotlib inline
import matplotlib. pyplot as plt
import pandas as pd
import numpy as np

# %%
x = [1, 2, 3, 4]

fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]);
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)
