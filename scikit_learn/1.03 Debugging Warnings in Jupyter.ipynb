# %% [markdown]
# ## 1.03 Debugging Warnings in Jupyter

# %% [markdown]
# ### Method 1: Ignore warnings using a warnings package.

# %% [markdown]
# Warnings can be ignored by filtering them out.

# %%
import warnings

# To ignore warnings 
warnings.filterwarnings('ignore')

# To reinstate warnings
warnings.filterwarnings('default')

# %% [markdown]
# ### Method 2: Upgrade/ change dependencies.

# %% [markdown]
# Updating packages is a good way to get rid of warnings.
#
# A common workflow would be to view the following resources:
# * [Managing conda packages](https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-pkgs.html)
# * [Updating packages](https://docs.conda.io/projects/conda/en/latest/user-guide/tasks/manage-pkgs.html#updating-packages)

# %%
# To show what version of scikit-learn you are using
import sklearn
sklearn.show_versions()
# Out:
# System:
#     python: 3.8.8 (default, Apr 13 2021, 12:59:45)  [Clang 10.0.0 ]
# executable: /Users/ashleycasanova/opt/anaconda3/bin/python
#    machine: macOS-10.16-x86_64-i386-64bit
#
# Python dependencies:
#           pip: 21.0.1
#    setuptools: 52.0.0.post20210125
#       sklearn: 0.24.1
#         numpy: 1.20.1
#         scipy: 1.6.2
#        Cython: 0.29.23
#        pandas: 1.2.4
#    matplotlib: 3.3.4
#        joblib: 1.0.1
# threadpoolctl: 2.1.0
#
# Built with OpenMP: True

# %%
# `conda list` will show you all of the packages you have
# To show what version of scikit-learn you are using via the terminal
# %conda list scikit-learn
# Out:
# # packages in environment at /Users/ashleycasanova/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# scikit-learn              0.24.1           py38hb2f4e1b_0
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# To update scikit-learn via the terminal
# %conda update scikit-learn
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
#
# Updating scikit-learn is constricted by
#
# anaconda -> requires scikit-learn==0.24.1=py38hb2f4e1b_0
#
# If you are sure you want an update of your package either try `conda update --all` or install a specific version of the package you want using `conda install <pkg>=<version>`
#
# done
#
# ## Package Plan ##
#
#   environment location: /Users/ashleycasanova/opt/anaconda3
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.11.0               |   py38hecd8cb5_0        14.4 MB
#     xmltodict-0.12.0           |     pyhd3eb1b0_0          13 KB
#     ------------------------------------------------------------
#                                            Total:        14.4 MB
#
# The following packages will be REMOVED:
#
#   python_abi-3.8-2_cp38
#
# The following packages will be UPDATED:
#
#   conda                               4.10.3-py38hecd8cb5_0 --> 4.11.0-py38hecd8cb5_0
#
# The following packages will be DOWNGRADED:
#
#   xmltodict                                     0.12.0-py_0 --> 0.12.0-pyhd3eb1b0_0
#
#
#
# Downloading and Extracting Packages
# conda-4.11.0         | 14.4 MB   | ##################################### | 100%
# xmltodict-0.12.0     | 13 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### If upgrade doesn't work, it may be that you do not have the right dependencies installed...

# %%
# To see what versions of scikit-learn are available from conda
# %conda search scikit-learn
# Out:
# Loading channels: done
# # Name                       Version           Build  Channel
# scikit-learn                  0.19.0 py27_nomklh2463853_2  pkgs/main
# scikit-learn                  0.19.0  py27h54286d7_2  pkgs/main
# scikit-learn                  0.19.0 py35_nomklh9245c0a_2  pkgs/main
# scikit-learn                  0.19.0  py35hd036984_2  pkgs/main
# scikit-learn                  0.19.0 py36_nomklh752ef42_2  pkgs/main
# scikit-learn                  0.19.0  py36h4cafacf_2  pkgs/main
# scikit-learn                  0.19.1 py27_nomklhd1ada06_0  pkgs/main
# scikit-learn                  0.19.1 py27_nomklhde7755b_0  pkgs/main
# scikit-learn                  0.19.1  py27h9788993_0  pkgs/main
# scikit-learn                  0.19.1  py27hf9f1f73_0  pkgs/main
# scikit-learn                  0.19.1 py35_nomklhf06d1bf_0  pkgs/main
# scikit-learn                  0.19.1  py35h2b554eb_0  pkgs/main
# scikit-learn                  0.19.1 py36_nomklh0ef093b_0  pkgs/main
# scikit-learn                  0.19.1 py36_nomklhde7755b_0  pkgs/main
# scikit-learn                  0.19.1  py36hf9f1f73_0  pkgs/main
# scikit-learn                  0.19.1  py36hffbff8c_0  pkgs/main
# scikit-learn                  0.19.1 py37_nomklhde7755b_0  pkgs/main
# scikit-learn                  0.19.1  py37hf9f1f73_0  pkgs/main
# scikit-learn                  0.19.2  py27h4f467ca_0  pkgs/main
# scikit-learn                  0.19.2  py27hebd9d1a_0  pkgs/main
# scikit-learn                  0.19.2  py35h4f467ca_0  pkgs/main
# scikit-learn                  0.19.2  py35hebd9d1a_0  pkgs/main
# scikit-learn                  0.19.2  py36h4f467ca_0  pkgs/main
# scikit-learn                  0.19.2  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.19.2  py37h4f467ca_0  pkgs/main
# scikit-learn                  0.19.2  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.0  py27h4f467ca_1  pkgs/main
# scikit-learn                  0.20.0  py27hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.0  py27hebd9d1a_1  pkgs/main
# scikit-learn                  0.20.0  py35h4f467ca_0  pkgs/main
# scikit-learn                  0.20.0  py35h4f467ca_1  pkgs/main
# scikit-learn                  0.20.0  py35hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.0  py35hebd9d1a_1  pkgs/main
# scikit-learn                  0.20.0  py36h4f467ca_0  pkgs/main
# scikit-learn                  0.20.0  py36h4f467ca_1  pkgs/main
# scikit-learn                  0.20.0  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.0  py36hebd9d1a_1  pkgs/main
# scikit-learn                  0.20.0  py37h4f467ca_0  pkgs/main
# scikit-learn                  0.20.0  py37h4f467ca_1  pkgs/main
# scikit-learn                  0.20.0  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.0  py37hebd9d1a_1  pkgs/main
# scikit-learn                  0.20.1  py27h27c97d8_0  pkgs/main
# scikit-learn                  0.20.1  py27h4f467ca_0  pkgs/main
# scikit-learn                  0.20.1  py27hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.1  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.20.1  py36h4f467ca_0  pkgs/main
# scikit-learn                  0.20.1  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.1  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.20.1  py37h4f467ca_0  pkgs/main
# scikit-learn                  0.20.1  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.2  py27h27c97d8_0  pkgs/main
# scikit-learn                  0.20.2  py27hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.2  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.20.2  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.2  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.20.2  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.3  py27h27c97d8_0  pkgs/main
# scikit-learn                  0.20.3  py27hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.3  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.20.3  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.20.3  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.20.3  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.1  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.21.1  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.1  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.21.1  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.2  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.21.2  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.2  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.21.2  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.3  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.21.3  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.21.3  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.21.3  py37hebd9d1a_0  pkgs/main
# scikit-learn                    0.22  py36h27c97d8_0  pkgs/main
# scikit-learn                    0.22  py36hebd9d1a_0  pkgs/main
# scikit-learn                    0.22  py37h27c97d8_0  pkgs/main
# scikit-learn                    0.22  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.22.1  py36h27c97d8_0  pkgs/main
# scikit-learn                  0.22.1  py36hebd9d1a_0  pkgs/main
# scikit-learn                  0.22.1  py37h27c97d8_0  pkgs/main
# scikit-learn                  0.22.1  py37hebd9d1a_0  pkgs/main
# scikit-learn                  0.22.1  py38h27c97d8_0  pkgs/main
# scikit-learn                  0.22.1  py38hebd9d1a_0  pkgs/main
# scikit-learn                  0.23.1  py36h58f5ce4_0  pkgs/main
# scikit-learn                  0.23.1  py36h603561c_0  pkgs/main
# scikit-learn                  0.23.1  py37h58f5ce4_0  pkgs/main
# scikit-learn                  0.23.1  py37h603561c_0  pkgs/main
# scikit-learn                  0.23.1  py38h58f5ce4_0  pkgs/main
# scikit-learn                  0.23.1  py38h603561c_0  pkgs/main
# scikit-learn                  0.23.2  py36h959d312_0  pkgs/main
# scikit-learn                  0.23.2  py37h959d312_0  pkgs/main
# scikit-learn                  0.23.2  py38h959d312_0  pkgs/main
# scikit-learn                  0.23.2  py39hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.1  py36hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.1  py37hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.1  py38hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.1  py39hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.2  py36hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.2  py37hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.2  py38hb2f4e1b_0  pkgs/main
# scikit-learn                  0.24.2  py39hb2f4e1b_0  pkgs/main
# scikit-learn                   1.0.1  py37hae1ba45_0  pkgs/main
# scikit-learn                   1.0.1  py38hae1ba45_0  pkgs/main
# scikit-learn                   1.0.1  py39hae1ba45_0  pkgs/main
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# To find which scikit-learn versions are available with a little more information
# %conda search scikit-learn --info
# Out:
# Loading channels: done
# scikit-learn 0.19.0 py27_nomklh2463853_2
# ----------------------------------------
# file name   : scikit-learn-0.19.0-py27_nomklh2463853_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py27_nomklh2463853_2
# build number: 2
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py27_nomklh2463853_2.conda
# md5         : 869bc16836ecfa5d84876ba117fba6ff
# timestamp   : 2017-11-03 18:59:04 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.0 py27h54286d7_2
# ----------------------------------
# file name   : scikit-learn-0.19.0-py27h54286d7_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py27h54286d7_2
# build number: 2
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py27h54286d7_2.conda
# md5         : ade65923948e7d14a669b019e45d62da
# timestamp   : 2017-09-15 07:57:21 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.0 py35_nomklh9245c0a_2
# ----------------------------------------
# file name   : scikit-learn-0.19.0-py35_nomklh9245c0a_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py35_nomklh9245c0a_2
# build number: 2
# size        : 3.5 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py35_nomklh9245c0a_2.conda
# md5         : 8ede6a955b2e09a564c7d22aa4a77190
# timestamp   : 2017-11-03 18:51:09 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.0 py35hd036984_2
# ----------------------------------
# file name   : scikit-learn-0.19.0-py35hd036984_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py35hd036984_2
# build number: 2
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py35hd036984_2.conda
# md5         : 3798d30b53efeb1fb04b85dc7c5f4e62
# timestamp   : 2017-09-15 08:11:41 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.0 py36_nomklh752ef42_2
# ----------------------------------------
# file name   : scikit-learn-0.19.0-py36_nomklh752ef42_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py36_nomklh752ef42_2
# build number: 2
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py36_nomklh752ef42_2.conda
# md5         : 15328cae7d89870721828eda56e67e8d
# timestamp   : 2017-11-03 19:10:32 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.0 py36h4cafacf_2
# ----------------------------------
# file name   : scikit-learn-0.19.0-py36h4cafacf_2.conda
# name        : scikit-learn
# version     : 0.19.0
# build       : py36h4cafacf_2
# build number: 2
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.0-py36h4cafacf_2.conda
# md5         : fe3fb764d17d30f3b5c1201f2d9a8223
# timestamp   : 2017-09-15 08:24:26 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.1 py27_nomklhd1ada06_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py27_nomklhd1ada06_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py27_nomklhd1ada06_0
# build number: 0
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py27_nomklhd1ada06_0.conda
# md5         : 430f562c8f4171e372fbfa094e65be70
# timestamp   : 2017-11-06 17:53:55 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.1 py27_nomklhde7755b_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py27_nomklhde7755b_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py27_nomklhde7755b_0
# build number: 0
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py27_nomklhde7755b_0.conda
# md5         : bc9b8bb5459a0fc34723facdc795a0eb
# timestamp   : 2018-07-05 16:26:34 UTC
# dependencies:
#   - blas 1.0 openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.1 py27h9788993_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py27h9788993_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py27h9788993_0
# build number: 0
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py27h9788993_0.conda
# md5         : 98e55fd69ad6c3bdb4ad47791418cd46
# timestamp   : 2017-10-23 13:25:34 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.1 py27hf9f1f73_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py27hf9f1f73_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py27hf9f1f73_0
# build number: 0
# size        : 3.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py27hf9f1f73_0.conda
# md5         : 1cc40e101d9c3170b0ebe5ce8a3ceb66
# timestamp   : 2018-07-05 16:50:48 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.1 py35_nomklhf06d1bf_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py35_nomklhf06d1bf_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py35_nomklhf06d1bf_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py35_nomklhf06d1bf_0.conda
# md5         : 8dd1c966e8096af38f4255478f8353b9
# timestamp   : 2017-11-06 17:40:19 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.1 py35h2b554eb_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py35h2b554eb_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py35h2b554eb_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py35h2b554eb_0.conda
# md5         : c5b505dac17d56d558fa3aa422a0a949
# timestamp   : 2017-10-23 13:24:52 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.1 py36_nomklh0ef093b_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py36_nomklh0ef093b_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py36_nomklh0ef093b_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py36_nomklh0ef093b_0.conda
# md5         : 0157a74065be49586e1ec2657ffffd91
# timestamp   : 2017-11-06 18:07:31 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - blas * openblas
#
#
# scikit-learn 0.19.1 py36_nomklhde7755b_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py36_nomklhde7755b_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py36_nomklhde7755b_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py36_nomklhde7755b_0.conda
# md5         : 1f5b157d7df710c606e3bc9ddee905f6
# timestamp   : 2018-07-05 17:14:03 UTC
# dependencies:
#   - blas 1.0 openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.19.1 py36hf9f1f73_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py36hf9f1f73_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py36hf9f1f73_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py36hf9f1f73_0.conda
# md5         : a99e9981cf573a217d34a99652d468dd
# timestamp   : 2018-07-05 17:32:46 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.19.1 py36hffbff8c_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py36hffbff8c_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py36hffbff8c_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py36hffbff8c_0.conda
# md5         : 6128213b95c81bcbbfae932c15f107fa
# timestamp   : 2017-10-23 13:24:42 UTC
# dependencies:
#   - libcxx >=4.0.1
#   - mkl >=2018.0.0,<2019.0a0
#   - numpy >=1.9.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - blas * mkl
#
#
# scikit-learn 0.19.1 py37_nomklhde7755b_0
# ----------------------------------------
# file name   : scikit-learn-0.19.1-py37_nomklhde7755b_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py37_nomklhde7755b_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py37_nomklhde7755b_0.conda
# md5         : 29a90ef434f83d65ccf442a9ce035a7f
# timestamp   : 2018-07-05 17:51:20 UTC
# dependencies:
#   - blas 1.0 openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.2.20,<0.2.21.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.1 py37hf9f1f73_0
# ----------------------------------
# file name   : scikit-learn-0.19.1-py37hf9f1f73_0.conda
# name        : scikit-learn
# version     : 0.19.1
# build       : py37hf9f1f73_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.1-py37hf9f1f73_0.conda
# md5         : 2860b6469cc7870357fed1f797ff0193
# timestamp   : 2018-07-05 18:09:48 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py27h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py27h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py27h4f467ca_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py27h4f467ca_0.conda
# md5         : fcf5383f11a6c0b14e24ea17c384650f
# timestamp   : 2018-09-20 21:27:41 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py27hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py27hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py27hebd9d1a_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py27hebd9d1a_0.conda
# md5         : 81aeeac6d6ef9d57a912a5aa9e14810e
# timestamp   : 2018-09-20 21:27:31 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py35h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py35h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py35h4f467ca_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py35h4f467ca_0.conda
# md5         : 4c8b43e93371d9a94ec30e347b0d51e7
# timestamp   : 2018-09-20 21:29:01 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py35hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py35hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py35hebd9d1a_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py35hebd9d1a_0.conda
# md5         : bc82431c0ed4cb804da7bfdc5c9c7752
# timestamp   : 2018-09-20 21:27:51 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py36h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py36h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py36h4f467ca_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py36h4f467ca_0.conda
# md5         : b16631e38b3d9bee5dbc81d97b20152f
# timestamp   : 2018-09-20 21:28:38 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py36hebd9d1a_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py36hebd9d1a_0.conda
# md5         : 9b568d3d3012332ce8b54572a798d5b8
# timestamp   : 2018-09-20 21:27:25 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py37h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py37h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py37h4f467ca_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py37h4f467ca_0.conda
# md5         : 9f266d31400a7158d4e9e34826ea821d
# timestamp   : 2018-09-20 21:27:46 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.19.2 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.19.2-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.19.2
# build       : py37hebd9d1a_0
# build number: 0
# size        : 3.6 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.19.2-py37hebd9d1a_0.conda
# md5         : 169b0476d653e73f474a2c340a64b05b
# timestamp   : 2018-09-20 21:26:04 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py27h4f467ca_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py27h4f467ca_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py27h4f467ca_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py27h4f467ca_1.conda
# md5         : 0c4f7a624198c1bdb3b6371e0fb8db8f
# timestamp   : 2018-09-27 14:18:41 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py27hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py27hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py27hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py27hebd9d1a_0.conda
# md5         : 6b621e5dcb967fb6c36692365f4fa176
# timestamp   : 2018-09-26 15:32:13 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py27hebd9d1a_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py27hebd9d1a_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py27hebd9d1a_1
# build number: 1
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py27hebd9d1a_1.conda
# md5         : 861819ced40f5bd03c9734932189a872
# timestamp   : 2018-09-27 14:16:40 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py35h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py35h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py35h4f467ca_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py35h4f467ca_0.conda
# md5         : b0dc6e1d64167b2767ce9b7bbc35050c
# timestamp   : 2018-09-26 15:37:19 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py35h4f467ca_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py35h4f467ca_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py35h4f467ca_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py35h4f467ca_1.conda
# md5         : e5af814a769320974f96ce61c5a9b359
# timestamp   : 2018-09-27 14:18:43 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py35hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py35hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py35hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py35hebd9d1a_0.conda
# md5         : e6b58cd1d3287ff142d6f001e2b03899
# timestamp   : 2018-09-26 15:35:44 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py35hebd9d1a_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py35hebd9d1a_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py35hebd9d1a_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py35hebd9d1a_1.conda
# md5         : 259b92c998379604572cbc4547557058
# timestamp   : 2018-09-27 14:13:46 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.5,<3.6.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py36h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py36h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py36h4f467ca_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py36h4f467ca_0.conda
# md5         : 1d6a12fab6d284ffc4368427054eec1b
# timestamp   : 2018-09-26 15:42:41 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py36h4f467ca_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py36h4f467ca_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py36h4f467ca_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py36h4f467ca_1.conda
# md5         : db81633a0a2fa6f6b90c20147685ca9c
# timestamp   : 2018-09-27 14:17:17 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py36hebd9d1a_0.conda
# md5         : d0f4991f1a1088c8364100c5724bb007
# timestamp   : 2018-09-26 15:31:29 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py36hebd9d1a_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py36hebd9d1a_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py36hebd9d1a_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py36hebd9d1a_1.conda
# md5         : 29ba4781c8360f2a1a3a647750d05366
# timestamp   : 2018-09-27 14:15:07 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py37h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py37h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py37h4f467ca_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py37h4f467ca_0.conda
# md5         : 0b7a243ca0d9ba6871f42ca7578b0a5f
# timestamp   : 2018-09-26 15:42:20 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py37h4f467ca_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py37h4f467ca_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py37h4f467ca_1
# build number: 1
# size        : 3.9 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py37h4f467ca_1.conda
# md5         : f55a7b7b8fd73426c7ffda9a96315f8f
# timestamp   : 2018-09-27 14:17:35 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.0-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py37hebd9d1a_0.conda
# md5         : b12e1db303a9a793977f210ce1ad3330
# timestamp   : 2018-09-26 15:34:51 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.0 py37hebd9d1a_1
# ----------------------------------
# file name   : scikit-learn-0.20.0-py37hebd9d1a_1.conda
# name        : scikit-learn
# version     : 0.20.0
# build       : py37hebd9d1a_1
# build number: 1
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.0-py37hebd9d1a_1.conda
# md5         : 6775a8bbd4373017bc9cf73d3761d365
# timestamp   : 2018-09-27 14:14:31 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py27h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py27h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py27h27c97d8_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py27h27c97d8_0.conda
# md5         : 4ae0b0fcd7369b67cbe93085498d080d
# timestamp   : 2018-12-14 19:58:32 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py27h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py27h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py27h4f467ca_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py27h4f467ca_0.conda
# md5         : 576390cefb51187f914fe6f8c9e5edd1
# timestamp   : 2018-11-23 19:24:22 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py27hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py27hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py27hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py27hebd9d1a_0.conda
# md5         : 24c243891a735aa5668644da386ae8a2
# timestamp   : 2018-11-23 05:41:16 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py36h27c97d8_0.conda
# md5         : 89fb88e139ba2a9502705cb9d6505228
# timestamp   : 2018-12-14 19:59:21 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py36h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py36h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py36h4f467ca_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py36h4f467ca_0.conda
# md5         : 6e7dafc96307191ffec50a2fc02f3f17
# timestamp   : 2018-11-23 05:31:22 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py36hebd9d1a_0.conda
# md5         : 365dd5deb694a1bb04feb47de3efd13f
# timestamp   : 2018-11-23 05:39:11 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py37h27c97d8_0.conda
# md5         : e6205845b7f1f1e50e306c8aab78bd6b
# timestamp   : 2018-12-14 19:59:21 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py37h4f467ca_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py37h4f467ca_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py37h4f467ca_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py37h4f467ca_0.conda
# md5         : 08e299150e9b2c8b83f68e5c5ca9830f
# timestamp   : 2018-11-23 05:39:32 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2018.0.3,<2019.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.1 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.1-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.1
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.1-py37hebd9d1a_0.conda
# md5         : c3f336052a7d5beadb61e600003ea66b
# timestamp   : 2018-11-23 05:31:02 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py27h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py27h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py27h27c97d8_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py27h27c97d8_0.conda
# md5         : f4792966aad0afd8c7f12936e2bfd70a
# timestamp   : 2018-12-27 19:35:02 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py27hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py27hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py27hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py27hebd9d1a_0.conda
# md5         : a4760abd85b6e297dd4f6aa004acf4c4
# timestamp   : 2018-12-27 19:31:50 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py36h27c97d8_0.conda
# md5         : 5903ec8bedde3e217278aaf518373803
# timestamp   : 2018-12-27 19:33:32 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py36hebd9d1a_0.conda
# md5         : c04dec2417938bb63374d38b8f7946e6
# timestamp   : 2018-12-27 19:29:32 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py37h27c97d8_0.conda
# md5         : 52ef6db0dbe2d1ea2178b094615c02f8
# timestamp   : 2018-12-27 19:15:07 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.2 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.2-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.2
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.2-py37hebd9d1a_0.conda
# md5         : adeae80a3d15c0e013ede1a6714e9ca0
# timestamp   : 2018-12-27 19:29:26 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py27h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py27h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py27h27c97d8_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py27h27c97d8_0.conda
# md5         : 87d10baa1e4ecfe0a8fcd5c81b9e5514
# timestamp   : 2019-03-12 19:40:11 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py27hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py27hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py27hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py27hebd9d1a_0.conda
# md5         : b2378d965a099c8a872b9aadbb6a20ab
# timestamp   : 2019-03-12 19:35:46 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=2.7,<2.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py36h27c97d8_0.conda
# md5         : db01a75c684424ab3786805c79244c60
# timestamp   : 2019-03-12 19:17:17 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.1 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py36hebd9d1a_0.conda
# md5         : f07364ea199612c5583dac099dccb7c5
# timestamp   : 2019-03-12 19:32:40 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py37h27c97d8_0.conda
# md5         : 59f338a84b1ba7dc1d5b900621094e5f
# timestamp   : 2019-03-12 19:38:48 UTC
# dependencies:
#   - blas 1.0 mkl
#   - libcxx >=4.0.1
#   - mkl >=2019.1,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.20.3 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.20.3-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.20.3
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.0 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.20.3-py37hebd9d1a_0.conda
# md5         : c418ab81c682661d5130d48e54e98141
# timestamp   : 2019-03-12 19:32:13 UTC
# dependencies:
#   - blas * openblas
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.1 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.1-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.1
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.1-py36h27c97d8_0.conda
# md5         : bbc4093f9c7ed9ceadb3328e9cf2076b
# timestamp   : 2019-05-18 00:25:23 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.3,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.1 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.1-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.1
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.1-py36hebd9d1a_0.conda
# md5         : 12db806dfefdb244bda168350686e57d
# timestamp   : 2019-05-18 00:24:05 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.1 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.1-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.1
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.1-py37h27c97d8_0.conda
# md5         : 77a680df3cdc497dd243ce485429a1d5
# timestamp   : 2019-05-18 00:25:00 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.3,<2020.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.1 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.1-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.1
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.1-py37hebd9d1a_0.conda
# md5         : 38d3df54b062b609607e6f503a4b80d2
# timestamp   : 2019-05-18 00:24:21 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.2 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.2-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.2
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.2-py36h27c97d8_0.conda
# md5         : 0ae8bcedfab26d684d117c850715d3fa
# timestamp   : 2019-06-04 11:08:27 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.2 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.2-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.2
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.2-py36hebd9d1a_0.conda
# md5         : 5a04c702f920c0b684daa6a17eb06881
# timestamp   : 2019-06-04 11:08:01 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.2 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.2-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.2
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.2-py37h27c97d8_0.conda
# md5         : 3dcda471e0ca96cbc13a7156461dbc57
# timestamp   : 2019-06-04 11:10:12 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.2 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.2-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.2
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.2-py37hebd9d1a_0.conda
# md5         : c8850b6a23a4bb0a48fd75e4ae194d52
# timestamp   : 2019-06-04 11:08:01 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.3 py36h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.3-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.3
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.3-py36h27c97d8_0.conda
# md5         : ed5103aaea431f170059289cff68f14d
# timestamp   : 2019-09-25 00:14:56 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.3 py36hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.3-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.3
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.3-py36hebd9d1a_0.conda
# md5         : 6135ef22f40d74fda609ff6148be5801
# timestamp   : 2019-09-25 00:05:34 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.21.3 py37h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.21.3-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.21.3
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.3-py37h27c97d8_0.conda
# md5         : d4b83f9b835329568cf293b3ce4eb485
# timestamp   : 2019-09-25 00:14:22 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.21.3 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.21.3-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.21.3
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.4 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.21.3-py37hebd9d1a_0.conda
# md5         : 988a14029a16cba2f7166e2714583749
# timestamp   : 2019-09-25 00:14:14 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.22 py36h27c97d8_0
# --------------------------------
# file name   : scikit-learn-0.22-py36h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.22
# build       : py36h27c97d8_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.22-py36h27c97d8_0.conda
# md5         : d82704bf2bc83cf38849659d60b1eaeb
# timestamp   : 2019-12-17 16:48:40 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.22 py36hebd9d1a_0
# --------------------------------
# file name   : scikit-learn-0.22-py36hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.22
# build       : py36hebd9d1a_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.22-py36hebd9d1a_0.conda
# md5         : 11d0309b8bd4997e3871e0aac489d341
# timestamp   : 2019-12-17 16:48:50 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#
#
# scikit-learn 0.22 py37h27c97d8_0
# --------------------------------
# file name   : scikit-learn-0.22-py37h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.22
# build       : py37h27c97d8_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# ...
# timestamp   : 2020-01-08 18:58:37 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.22.1 py37hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.22.1-py37hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.22.1
# build       : py37hebd9d1a_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.22.1-py37hebd9d1a_0.conda
# md5         : 51e2464422170197e66461f9f740e92a
# timestamp   : 2020-01-08 18:58:36 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#
#
# scikit-learn 0.22.1 py38h27c97d8_0
# ----------------------------------
# file name   : scikit-learn-0.22.1-py38h27c97d8_0.conda
# name        : scikit-learn
# version     : 0.22.1
# build       : py38h27c97d8_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.22.1-py38h27c97d8_0.conda
# md5         : eb399ff909f02895a53f53d430650a48
# timestamp   : 2020-01-29 01:22:01 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - llvm-openmp
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#
#
# scikit-learn 0.22.1 py38hebd9d1a_0
# ----------------------------------
# file name   : scikit-learn-0.22.1-py38hebd9d1a_0.conda
# name        : scikit-learn
# version     : 0.22.1
# build       : py38hebd9d1a_0
# build number: 0
# size        : 4.7 MB
# license     : BSD 3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.22.1-py38hebd9d1a_0.conda
# md5         : cbe2c3f9111f32d664a6b7e04f874aa6
# timestamp   : 2020-01-29 01:21:37 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=4.0.1
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp
#   - numpy >=1.11.3,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#
#
# scikit-learn 0.23.1 py36h58f5ce4_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py36h58f5ce4_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py36h58f5ce4_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py36h58f5ce4_0.conda
# md5         : c593688123ff12fbc12c61317e334a50
# timestamp   : 2020-06-22 20:10:34 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.1 py36h603561c_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py36h603561c_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py36h603561c_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py36h603561c_0.conda
# md5         : 4edcae4afcbe8658f250ddce07bac57b
# timestamp   : 2020-06-22 20:11:00 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.1 py37h58f5ce4_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py37h58f5ce4_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py37h58f5ce4_0
# build number: 0
# size        : 4.6 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py37h58f5ce4_0.conda
# md5         : 6e0d1bddd74e1336eb246c2e68972466
# timestamp   : 2020-06-18 18:07:19 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.1 py37h603561c_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py37h603561c_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py37h603561c_0
# build number: 0
# size        : 4.6 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py37h603561c_0.conda
# md5         : 4dd8c1e86092ba61af389e32aa0158da
# timestamp   : 2020-06-18 18:17:47 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.1 py38h58f5ce4_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py38h58f5ce4_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py38h58f5ce4_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py38h58f5ce4_0.conda
# md5         : e37c929dfeb367ac9649d630204bda0c
# timestamp   : 2020-06-18 18:07:07 UTC
# dependencies:
#   - blas * openblas
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - libopenblas >=0.3.3,<1.0a0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.1 py38h603561c_0
# ----------------------------------
# file name   : scikit-learn-0.23.1-py38h603561c_0.conda
# name        : scikit-learn
# version     : 0.23.1
# build       : py38h603561c_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.1-py38h603561c_0.conda
# md5         : c8e4c456c5d0938da0fcb9648c3a3ba8
# timestamp   : 2020-06-18 18:17:14 UTC
# dependencies:
#   - blas 1.0 mkl
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - mkl >=2019.4,<2020.0a0
#   - mkl-service >=2,<3.0a0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.2 py36h959d312_0
# ----------------------------------
# file name   : scikit-learn-0.23.2-py36h959d312_0.conda
# name        : scikit-learn
# version     : 0.23.2
# build       : py36h959d312_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.2-py36h959d312_0.conda
# md5         : 3af59a13679906100928b5e28134a005
# timestamp   : 2020-08-25 17:39:51 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.2 py37h959d312_0
# ----------------------------------
# file name   : scikit-learn-0.23.2-py37h959d312_0.conda
# name        : scikit-learn
# version     : 0.23.2
# build       : py37h959d312_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.2-py37h959d312_0.conda
# md5         : 5f5e341d77a279a53021362b2a23d252
# timestamp   : 2020-08-25 17:40:05 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.2 py38h959d312_0
# ----------------------------------
# file name   : scikit-learn-0.23.2-py38h959d312_0.conda
# name        : scikit-learn
# version     : 0.23.2
# build       : py38h959d312_0
# build number: 0
# size        : 4.7 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.2-py38h959d312_0.conda
# md5         : 9549a7d9d5f6f18aeeb062e002a6dad4
# timestamp   : 2020-08-25 17:39:12 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.14.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.23.2 py39hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.23.2-py39hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.23.2
# build       : py39hb2f4e1b_0
# build number: 0
# size        : 4.8 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.23.2-py39hb2f4e1b_0.conda
# md5         : bab98f434480b8cb0ad988a820933c70
# timestamp   : 2020-12-11 18:50:01 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.9,<3.10.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.24.1 py36hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.1-py36hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.1
# build       : py36hb2f4e1b_0
# build number: 0
# size        : 4.8 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.1-py36hb2f4e1b_0.conda
# md5         : 58afa2097bc83451c01a5432b3ead9a2
# timestamp   : 2021-02-27 17:29:30 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.24.1 py37hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.1-py37hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.1
# build       : py37hb2f4e1b_0
# build number: 0
# size        : 4.8 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.1-py37hb2f4e1b_0.conda
# md5         : f855b9cff4f51ba2de45010257e9cace
# timestamp   : 2021-02-27 17:29:15 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.24.1 py38hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.1-py38hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.1
# build       : py38hb2f4e1b_0
# build number: 0
# size        : 4.9 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.1-py38hb2f4e1b_0.conda
# md5         : 545496be34d2ba530fce5f943d7b1c99
# timestamp   : 2021-02-27 17:29:09 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.24.1 py39hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.1-py39hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.1
# build       : py39hb2f4e1b_0
# build number: 0
# size        : 5.0 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.1-py39hb2f4e1b_0.conda
# md5         : 1aaa545080bf2ab9a260af83dd358364
# timestamp   : 2021-02-27 17:29:18 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.9,<3.10.0a0
#   - scipy
#   - threadpoolctl
#
#
# scikit-learn 0.24.2 py36hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.2-py36hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.2
# build       : py36hb2f4e1b_0
# build number: 0
# size        : 4.9 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.2-py36hb2f4e1b_0.conda
# md5         : c670c970e807489e02beff389f2b7ad0
# timestamp   : 2021-05-18 20:44:21 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.6,<3.7.0a0
#   - scipy >=0.19.1
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 0.24.2 py37hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.2-py37hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.2
# build       : py37hb2f4e1b_0
# build number: 0
# size        : 4.8 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.2-py37hb2f4e1b_0.conda
# md5         : a8ad422dbc0d767f0fa612e4ea900ac0
# timestamp   : 2021-05-18 20:44:25 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy >=0.19.1
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 0.24.2 py38hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.2-py38hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.2
# build       : py38hb2f4e1b_0
# build number: 0
# size        : 4.9 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.2-py38hb2f4e1b_0.conda
# md5         : cab481bb97698d6dea0d7d70ade7ce5d
# timestamp   : 2021-05-18 20:45:33 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy >=0.19.1
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 0.24.2 py39hb2f4e1b_0
# ----------------------------------
# file name   : scikit-learn-0.24.2-py39hb2f4e1b_0.conda
# name        : scikit-learn
# version     : 0.24.2
# build       : py39hb2f4e1b_0
# build number: 0
# size        : 5.0 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-0.24.2-py39hb2f4e1b_0.conda
# md5         : 20fbb89aeaccd894e5e032998832a875
# timestamp   : 2021-05-18 20:45:50 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=10.0.0
#   - llvm-openmp >=10.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.9,<3.10.0a0
#   - scipy >=0.19.1
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 1.0.1 py37hae1ba45_0
# ---------------------------------
# file name   : scikit-learn-1.0.1-py37hae1ba45_0.conda
# name        : scikit-learn
# version     : 1.0.1
# build       : py37hae1ba45_0
# build number: 0
# size        : 5.1 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-1.0.1-py37hae1ba45_0.conda
# md5         : 8a5773d624cc1e6e84c3cecca752ac1a
# timestamp   : 2021-10-27 12:53:55 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=12.0.0
#   - llvm-openmp >=12.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.7,<3.8.0a0
#   - scipy >=1.1.0
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 1.0.1 py38hae1ba45_0
# ---------------------------------
# file name   : scikit-learn-1.0.1-py38hae1ba45_0.conda
# name        : scikit-learn
# version     : 1.0.1
# build       : py38hae1ba45_0
# build number: 0
# size        : 5.2 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-1.0.1-py38hae1ba45_0.conda
# md5         : c24518581fdce6e9bd10043f57fe6b50
# timestamp   : 2021-10-27 13:06:25 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=12.0.0
#   - llvm-openmp >=12.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.8,<3.9.0a0
#   - scipy >=1.1.0
#   - threadpoolctl >=2.0.0
#
#
# scikit-learn 1.0.1 py39hae1ba45_0
# ---------------------------------
# file name   : scikit-learn-1.0.1-py39hae1ba45_0.conda
# name        : scikit-learn
# version     : 1.0.1
# build       : py39hae1ba45_0
# build number: 0
# size        : 5.3 MB
# license     : BSD-3-Clause
# subdir      : osx-64
# url         : https://repo.anaconda.com/pkgs/main/osx-64/scikit-learn-1.0.1-py39hae1ba45_0.conda
# md5         : 2b71cf850dd92098e8632cc118f86835
# timestamp   : 2021-10-27 13:18:28 UTC
# dependencies:
#   - joblib >=0.11
#   - libcxx >=12.0.0
#   - llvm-openmp >=12.0.0
#   - numpy >=1.16.6,<2.0a0
#   - python >=3.9,<3.10.0a0
#   - scipy >=1.1.0
#   - threadpoolctl >=2.0.0
#
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# The cell above tells us the dependencies required to update scikit learn to version 0.19..

# %%
# Check if current environment is running a python version that is compatible with scikit-learn version 0.24.1 (python >=3.9,<3.10)
# %conda list python
# Out:
# # packages in environment at /Users/ashleycasanova/opt/anaconda3:
# #
# # Name                    Version                   Build  Channel
# ipython                   7.22.0           py38h01d92e1_0
# ipython_genutils          0.2.0              pyhd3eb1b0_1
# msgpack-python            1.0.2            py38hf7b0b51_1
# python                    3.8.8                h88f2d9e_5
# python-dateutil           2.8.1              pyhd3eb1b0_0
# python-jsonrpc-server     0.4.0                      py_0
# python-language-server    0.36.2             pyhd3eb1b0_0
# python-libarchive-c       2.9                pyhd3eb1b0_1
# python.app                3                py38h9ed2024_0
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# >Note: Our package manager (conda) makes sure that we have the correct dependencies installed.

# %% [markdown]
# #### If we want to install a specific version of scikit-learn:
#
# 1. Uninstall the current version and it's coresponding dependencies.
# ```terminal
# conda uninstall scikit-learn python
# ```
#
# >Note: conda will automatically uninstall any packages that list scikit-learn or python as dependencies. Therefore we will want to reinstall all of our packages in addition to the specific versions we want to use in our environment as they were likely removed in the process.
#
# 2. Next, we can install the specific package versions we want.
# ```terminal
# conda install python=3.6.9 scikit-learn=0.22 matplotlib numpy pandas jupyter

# %% [markdown]
# >Note: This example is from conda environment.
