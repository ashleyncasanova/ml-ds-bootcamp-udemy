# %% [markdown]
# #### **<span style="color:hotpink">Matplotlib</span>**

# %% [markdown]
# Import tools:

# %%
# %matplotlib inline 
# prints plot inside notebook
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# Plotting

# %%
plt.plot()
# plt.plot(); # semicolon removes brackets '[]'
# Out:
# []

# %%
plt.plot()
plt.show() # also removes brackets '[]'

# %% [markdown]
# Adding Data:

# %%
plt.plot([1,2,3,4]); # adds data directly

# %%
# creat data to be inserted
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %% [markdown]
# #### Pyplot vs. Object Oriented (OO) Interface
#
# * While it is easy to quickly generate plots with the matplotlib.pyplot module, the use of <span style="color:hotpink">object-oriented approach is recommended</span> as it gives more <span style="color:hotpink">control and customization</span> of your plots.
# * The main idea behind using the more formal object-oriented method is to <span style="color:hotpink">create figure objects and then just call methods or attributes off of that object</span>.
# * In object-oriented interface, Pyplot is used only for a few functions such as figure creation, and the user explicitly creates and keeps track of the figure and axes objects.
# * The <span style="color:hotpink">pyplot approach doesn't really scale when we are required to make multiple plots </span>or when we have to make intricate plots that require a lot of customisation

# %% [markdown]
# Pyplot Interface:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.figure()
plt.plot(x,y)
plt.title("Title")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(["legend"])
plt.show()

# %% [markdown]
# OO Interface (3 methods)

# %%
# 1st method
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

fig = plt.figure() # creates a figure instance (empty canvas)
ax = fig.add_subplot() # adds some axes
ax.plot(x,y)
ax.set_title("Title")
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
fig.legend(["legend"])
plt.show()

# %%
# 2nd method
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

fig = plt.figure() # creates a figure instance (empty canvas)
ax = fig.add_axes([1,1,1,1]) # [left, bottom, width, height]
ax.plot(x,y)
ax.set_title("Title")
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
fig.legend(["legend"])
plt.show()

# %%
# 3rd method (recommended)
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

fig, ax = plt.subplots() # mult subplots in same fig
ax.plot(x,y)
ax.set_title("Title")
ax.set_xlabel("x-axis")
ax.set_ylabel("y-axis")
fig.legend(["legend"])
plt.show()

# %% [markdown]
# Example of multiple plots...

# %%
# Pyplot Interface
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

plt.figure()
plt.plot(x,y)
plt.plot(x,np.square(x))
plt.title("Title")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.legend(["x", "x^2"])
plt.show()

# %%
# Object Oriented Interface
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

fig, ax1 = plt.subplots()
ax1.set_title("Title")
ax1.set_xlabel("x-axis")
ax1.set_ylabel("y-axis")
ax1.plot(x,y,"blue")

ax2 = ax1.twinx() # create another y-axis sharing a common x-axis
ax2.set_xlabel("x-axis")
ax2.set_ylabel("y-axis")
ax2.plot(x,np.square(x),"orange")

fig.legend(["x","x^2"])
plt.show()

# %% [markdown]
# Example Workflow

# %%
# 0. import tools
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prep data
x = [1,2,3,4]
y = [11, 22, 33, 44]

# 2. Setup plot
fig, ax = plt.subplots(figsize=(3,3)) # (width, height)

# 3. Plot Data
ax.plot(x,y);

# 4. Customize plot
ax.set(title="Simple Plot",
       xlabel="x-axis",
       ylabel="y-axis")

# 5. Save & share
fig.savefig("./sample-plot2.png")

# %% [markdown]
# Making Figures with Numpy Arays

# %%
# Let's create some data to work with...
x = np.linspace(0,10,100) # array with 100 evenly spaced elements from 0-10
x[:10] # returns first 10 elements
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %% [markdown]
# Line Plot

# %%
fig, ax = plt.subplots()
# ax.plot(x, x**2);
ax.plot(x, np.exp(x));
# ax.plot(x, np.sin(x));

# %% [markdown]
# Scatter Plot

# %%
# Scatter Plot
fig, ax = plt.subplots()
# ax.scatter(x, x**2);
# ax.scatter(x, np.exp(x));
ax.scatter(x, np.sin(x));

# %% [markdown]
# Bar Plot

# %%
# first some data...
nut_prices = {"Almond":10,
              "Peanut":8,
              "Cashew":12}
x = list(nut_prices.keys())
y = list(nut_prices.values())

nut_prices, x, y
# Out:
# ({'Almond': 10, 'Peanut': 8, 'Cashew': 12},
#  ['Almond', 'Peanut', 'Cashew'],
#  [10, 8, 12])

# %%
fig, ax=plt.subplots() # we need to reset the figure and axis in new cells
ax.bar(x, y)
ax.set(title="Nut Prices", ylabel="Prices ($)");

# %%
# Horizontal Bar plot
fig, ax =plt.subplots()
ax.barh(x,y)
ax.set(title="Nut Prices", xlabel="Prices ($)");

# %% [markdown]
# Histogram

# %%
# Let's create some data
normal_dist = np.random.randn(1000) # returns random array of normally distributed #'s
uniform_dist = np.random.random(1000) # "" uniformly distributed #'s

# %%
fig, ax = plt.subplots()
ax.hist(normal_dist)
ax.set(title="Histogram of Normal Distribution", xlabel="Value", ylabel="Frequency");

# %%
fig, ax=plt.subplots()
ax.hist(uniform_dist)
ax.set(title="Histogram of Uniform Distribution", xlabel="Value", ylabel="Frequency");

# %% [markdown]
# Plotting From Pandas
# ___
#
# >It is more common to plot from a pandas dataframe than from a numpy array.

# %%
# Import Data
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Read in Pandas Data Frame
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
# remove symbols from price column using regex
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
# <ipython-input-32-a21abd5e0f76>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.03581962, 0.42846869, 0.61674651, 0.11804049],
#        [0.06069715, 0.86212068, 0.02889854, 0.59413345],
#        [0.46409511, 0.29296635, 0.43228088, 0.70840723],
#        [0.07647103, 0.23648801, 0.63407236, 0.07477306],
#        [0.30595106, 0.79245283, 0.75309895, 0.86643192],
#        [0.16535736, 0.9049309 , 0.96889504, 0.21879562],
#        [0.45017226, 0.58763483, 0.11884493, 0.22808046],
#        [0.58021364, 0.293722  , 0.0071299 , 0.40729731],
#        [0.07533759, 0.0907904 , 0.25986506, 0.58315003],
#        [0.36865498, 0.89195681, 0.95842782, 0.423574  ]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.035820  0.428469  0.616747  0.118040
# 1  0.060697  0.862121  0.028899  0.594133
# 2  0.464095  0.292966  0.432281  0.708407
# 3  0.076471  0.236488  0.634072  0.074773
# 4  0.305951  0.792453  0.753099  0.866432
# 5  0.165357  0.904931  0.968895  0.218796
# 6  0.450172  0.587635  0.118845  0.228080
# 7  0.580214  0.293722  0.007130  0.407297
# 8  0.075338  0.090790  0.259865  0.583150
# 9  0.368655  0.891957  0.958428  0.423574

# %%
df.plot.bar();

# %%
car_sales.plot.bar(x='Make',y='Odometer (KM)');

# %%
car_sales.plot(x='Make', y='Odometer (KM)', kind='bar');

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
data = car_sales.groupby(["Make"]).mean()
data
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
data.plot(y='Odometer (KM)', kind='bar');

# %%
car_sales['Odometer (KM)'].plot.hist();

# %%
car_sales.plot.hist(figsize=(10,10), subplots=True);

# %% [markdown]
# It's using the same scale for each histogram. Not ideal
#
# ___
# OOP - subplots
#
# histograms are good for visualizing distributions
#
# we have been plotting directly from pandas using the stateless method
#
# lets look at using oop for more complicated plotting

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# let's create a subset of our df
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
len(heart_disease), len(over_50)
# Out:
# (303, 208)

# %%
# Pyplot Method
over_50.plot(kind='scatter',
             x='age',
             y='chol',
             c='target',
             figsize=(10,6));

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
plt.style.use("seaborn-whitegrid")
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
x = np.random.rand(10,4)
x
# Out:
# array([[0.47773031, 0.33938748, 0.64888933, 0.4133588 ],
#        [0.68316161, 0.30929258, 0.18780828, 0.94986188],
#        [0.01177684, 0.22032318, 0.27376827, 0.10947415],
#        [0.87702241, 0.89978803, 0.7766349 , 0.19875175],
#        [0.80114968, 0.24474236, 0.93511315, 0.90583835],
#        [0.75748246, 0.57462518, 0.18677844, 0.14916778],
#        [0.58239079, 0.42457843, 0.31206991, 0.29230131],
#        [0.11577885, 0.21888363, 0.65929223, 0.61913867],
#        [0.07616822, 0.98618806, 0.37910585, 0.42240113],
#        [0.01875984, 0.07819376, 0.00978077, 0.69168111]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.477730  0.339387  0.648889  0.413359
# 1  0.683162  0.309293  0.187808  0.949862
# 2  0.011777  0.220323  0.273768  0.109474
# 3  0.877022  0.899788  0.776635  0.198752
# 4  0.801150  0.244742  0.935113  0.905838
# 5  0.757482  0.574625  0.186778  0.149168
# 6  0.582391  0.424578  0.312070  0.292301
# 7  0.115779  0.218884  0.659292  0.619139
# 8  0.076168  0.986188  0.379106  0.422401
# 9  0.018760  0.078194  0.009781  0.691681

# %%
ax = df.plot(kind="bar");
ax.set(title="Random Number Bar Graph from DataFrame",
       xlabel="Row Number",
       ylabel="Random Number")
ax.legend().set_visible(True)

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500

# %%
type(car_sales["Price"])
# Out:
# pandas.core.series.Series

# %%
car_sales["Price"].astype(int).sum()
# Out:
# 76450

# %%
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales["Price"].sum()
# Out:
# 76450

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Total Sales
# 0  Toyota  White         150043      4   4000         4000
# 1   Honda    Red          87899      4   5000         9000
# 2  Toyota   Blue          32549      3   7000        16000
# 3     BMW  Black          11179      5  22000        38000
# 4  Nissan  White         213095      4   3500        41500
# 5  Toyota  Green          99213      4   4500        46000
# 6   Honda   Blue          45698      4   7500        53500
# 7   Honda   Blue          54738      4   7000        60500
# 8  Toyota  White          60000      4   6250        66750
# 9  Nissan  White          31600      4   9700        76450

# %%
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
plt.style.use('default') # resets to default style

fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(over_50['age'],
                     over_50['chol'],
                     c = over_50['target'])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(y=over_50["chol"].mean(),
           c='b', # sets hline to blue
           linestyle='--',
           label='Average')
ax.legend(*scatter.legend_elements(), title="Target");

# %%
plt.style.use('default')
fig, ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(over_50['age'],
                     over_50['chol'],
                     c=over_50['target'],
                     cmap='winter') # color map - changes color scheme.
ax.set(title='Heart Disease and Cholesterol Levels',
       xlabel='Age',
       ylabel='Cholesterol')
ax.axhline(y=over_50['chol'].mean(),
           c='red', # changes axhline to red
           linestyle='--',
           label='Average')
ax.legend(*scatter.legend_elements(), title='Target');

# %%
fig, ax =  plt.subplots(figsize=(10,6))
scatter = ax.scatter(over_50['age'],
                     over_50['chol'],
                     c=over_50['target'],
                     cmap='winter')
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")
ax.axhline(over_50['chol'].mean(),
           linestyle='--',
           c='r',
           label='Average');
# ax.legend().set_visible(True) # shows axhline label
ax.legend(*scatter.legend_elements(),
          title='Target')

# %%
# Let's create multiple subplots within a single figure...
fig, (ax0, ax1) = plt.subplots(nrows=2,
                               ncols=1,
                               sharex=True,
                               figsize=(10,10))

fig.suptitle('Heart Disease Analysis',
             fontsize=16,
             fontweight='bold');

# Subplot 1: Heart Disease and Cholesterol Levels
scatter = ax0.scatter(over_50['age'],
                      over_50['chol'],
                      c=over_50['target'],
                      cmap='winter')

ax0.set(title='Heart Disease and Cholesterol Levels',
        ylabel='Cholesterol')

ax0.set_ylim(100,450)

ax0.axhline(over_50['chol'].mean(),
            color='r',
            linestyle='--',
            label='Average')

ax0.legend(*scatter.legend_elements(), 
           title="Target")

# Subplot 2: Heart Disease and Max Heart Rate Levels
scatter = ax1.scatter(over_50['age'],
                      over_50['thalach'],
                      c=over_50['target'],
                      cmap='summer')

ax1.set(title='Heart Disease and Max Heart Rate Levels',
        xlabel='Age',
        ylabel='Max Heart Rate')

ax1.set_ylim(80.180)

ax1.set_xlim(50,70)

ax1.axhline(over_50['thalach'].mean(),
            color='orange',
            linestyle='--',
            label='Average')

ax1.legend(*scatter.legend_elements(),
           title='Target');
